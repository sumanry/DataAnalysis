# %%
import pandas

# %%
df1 = pandas.read_csv("traffic.csv")

# %%
df1
# Out:
#    Date  Visitors  BR    Country  Clicks            Day status Test
# 0     1      1500  20        USA      20    TuesdayJune      A    A
# 1     2       700  25         UK      35  WednesdayJune      A    A
# 2     3       900  15      India      37   ThursdayJune      A    A
# 3     4       400  35        USA      12     FridayJune      A    A
# 4     5       500  14     Canada      35   SaturdayJune      A    A
# 5     6       700  15      India      32     SundayJune      A    A
# 6     7       600  20      India      37     MondayJune      A    A
# 7     8       700  16        USA      40    TuesdayJune      A    A
# 8     9      1200  27        USA      52  WednesdayJune      A    A
# 9    10      1400  32  Australia      57   ThursdayJune      A    A

# %%
df2 = df1.T

# %%
df2
# Out:
#                     0              1             2           3             4  \
# Date                1              2             3           4             5
# Visitors         1500            700           900         400           500
# BR                 20             25            15          35            14
# Country           USA             UK         India         USA        Canada
# Clicks             20             35            37          12            35
# Day       TuesdayJune  WednesdayJune  ThursdayJune  FridayJune  SaturdayJune
# status              A              A             A           A             A
# Test                A              A             A           A             A
#
#                    5           6            7              8             9
# Date               6           7            8              9            10
# Visitors         700         600          700           1200          1400
# ...

# %%
df1 = df2.T
df1
# Out:
#   Date Visitors  BR    Country Clicks            Day status Test
# 0    1     1500  20        USA     20    TuesdayJune      A    A
# 1    2      700  25         UK     35  WednesdayJune      A    A
# 2    3      900  15      India     37   ThursdayJune      A    A
# 3    4      400  35        USA     12     FridayJune      A    A
# 4    5      500  14     Canada     35   SaturdayJune      A    A
# 5    6      700  15      India     32     SundayJune      A    A
# 6    7      600  20      India     37     MondayJune      A    A
# 7    8      700  16        USA     40    TuesdayJune      A    A
# 8    9     1200  27        USA     52  WednesdayJune      A    A
# 9   10     1400  32  Australia     57   ThursdayJune      A    A

# %%
df1["status"] = ["A", "A", "A", "A", "A", "A", "A", "A", "A", "A"]
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day status
# 0     1      1500  20        USA      20    Tuesday      A
# 1     2       700  25         UK      35  Wednesday      A
# 2     3       900  15      India      37   Thursday      A
# 3     4       400  35        USA      12     Friday      A
# 4     5       500  14     Canada      35   Saturday      A
# 5     6       700  15      India      32     Sunday      A
# 6     7       600  20      India      37     Monday      A
# 7     8       700  16        USA      40    Tuesday      A
# 8     9      1200  27        USA      52  Wednesday      A
# 9    10      1400  32  Australia      57   Thursday      A

# %%
df1["Test"] = ["A"]*10
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day status Test
# 0     1      1500  20        USA      20    Tuesday      A    A
# 1     2       700  25         UK      35  Wednesday      A    A
# 2     3       900  15      India      37   Thursday      A    A
# 3     4       400  35        USA      12     Friday      A    A
# 4     5       500  14     Canada      35   Saturday      A    A
# 5     6       700  15      India      32     Sunday      A    A
# 6     7       600  20      India      37     Monday      A    A
# 7     8       700  16        USA      40    Tuesday      A    A
# 8     9      1200  27        USA      52  Wednesday      A    A
# 9    10      1400  32  Australia      57   Thursday      A    A

# %%
df1.shape
# Out:
# (10, 8)

# %%
df1.shape[0]
# Out:
# 10

# %%
df1["Test"] = ["A"]*df1.shape[0]

# %%
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day status Test
# 0     1      1500  20        USA      20    Tuesday      A    A
# 1     2       700  25         UK      35  Wednesday      A    A
# 2     3       900  15      India      37   Thursday      A    A
# 3     4       400  35        USA      12     Friday      A    A
# 4     5       500  14     Canada      35   Saturday      A    A
# 5     6       700  15      India      32     Sunday      A    A
# 6     7       600  20      India      37     Monday      A    A
# 7     8       700  16        USA      40    Tuesday      A    A
# 8     9      1200  27        USA      52  Wednesday      A    A
# 9    10      1400  32  Australia      57   Thursday      A    A

# %%
df1["Day"] = df1["Day"]+ "June"

# %%
df1
# Out:
#    Date  Visitors  BR    Country  Clicks            Day status Test
# 0     1      1500  20        USA      20    TuesdayJune      A    A
# 1     2       700  25         UK      35  WednesdayJune      A    A
# 2     3       900  15      India      37   ThursdayJune      A    A
# 3     4       400  35        USA      12     FridayJune      A    A
# 4     5       500  14     Canada      35   SaturdayJune      A    A
# 5     6       700  15      India      32     SundayJune      A    A
# 6     7       600  20      India      37     MondayJune      A    A
# 7     8       700  16        USA      40    TuesdayJune      A    A
# 8     9      1200  27        USA      52  WednesdayJune      A    A
# 9    10      1400  32  Australia      57   ThursdayJune      A    A

# %%
df1.drop(8,0)
# Out:
# /tmp/ipykernel_75341/3587457929.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(8,0)
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df1.drop(df1.columns[5],1)
# Out:
# /tmp/ipykernel_75341/2869134411.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(df1.columns[5],1)
#    Date  Visitors  BR    Country  Clicks
# 0     1      1500  20        USA      20
# 1     2       700  25         UK      35
# 2     3       900  15      India      37
# 3     4       400  35        USA      12
# 4     5       500  14     Canada      35
# 5     6       700  15      India      32
# 6     7       600  20      India      37
# 7     8       700  16        USA      40
# 8     9      1200  27        USA      52
# 9    10      1400  32  Australia      57

# %%
df1.columns[5]
# Out:
# 'Day'

# %%
df1.index[5]
# Out:
# 5

# %%
df1.drop(df1.index[2],0)
# Out:
# /tmp/ipykernel_75341/582038251.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(df1.index[2],0)
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df1.loc[2:5, "Country":"Day"]
# Out:
#   Country  Clicks       Day
# 2   India      37  Thursday
# 3     USA      12    Friday
# 4  Canada      35  Saturday
# 5   India      32    Sunday

# %%
df1["Country"]
# Out:
# 0          USA
# 1           UK
# 2        India
# 3          USA
# 4       Canada
# 5        India
# 6        India
# 7          USA
# 8          USA
# 9    Australia
# Name: Country, dtype: object

# %%
df1.loc[3, "Country"]
# Out:
# 'USA'

# %%
df1.loc[2:5, "Country": "Day"]
# Out:
#   Country  Clicks       Day
# 2   India      37  Thursday
# 3     USA      12    Friday
# 4  Canada      35  Saturday
# 5   India      32    Sunday

# %%
df2 = df1.loc[3, "Clicks"]
df2
# Out:
# 12

# %%
df2 = df1.loc[:, "Clicks"]
df2
# Out:
# 0    20
# 1    35
# 2    37
# 3    12
# 4    35
# 5    32
# 6    37
# 7    40
# 8    52
# 9    57
# Name: Clicks, dtype: int64

# %%
df1.iloc[6:9 , 1:5]
# Out:
#    Visitors  BR Country  Clicks
# 6       600  20   India      37
# 7       700  16     USA      40
# 8      1200  27     USA      52

# %%
df1.iloc[5, 1:5]
# Out:
# Visitors      700
# BR             15
# Country     India
# Clicks         32
# Name: 5, dtype: object

# %%
df1.iloc[5, 1:3]
# Out:
# Visitors    700
# BR           15
# Name: 5, dtype: object

# %%
df1.iloc[5, 1:6]
# Out:
# Visitors       700
# BR              15
# Country      India
# Clicks          32
# Day         Sunday
# Name: 5, dtype: object
